# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaMunozD/TrabajoArreglos/blob/main/EntregaTrabajoGr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = '/content/Precio_m_ximo_de_venta_de_los_medicamentos_por_presentaci_n_comercial_20240413.csv'
df = pd.read_csv(url)

df_sorted = df.sort_values(by='Descripción Principio Activo', ascending=True)
print(df_sorted)

#Gráfica de barras
plt.bar(df_sorted['Descripción Principio Activo'], df_sorted['Forma Farmacéutica'])
plt.xlabel('Descripción Principio Activo')
plt.ylabel('Forma Farmacéutica')
plt.title('Forma Farmacéutica por descripción principio activo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
print(df.columns)
# Out:
#          No.      ATC    ID MR Descripción Principio Activo  \
# 30011    222  L04AA24       61                    Abatacept
# 30012    223  L04AA24       61                    Abatacept
# 33728   3988  L04AA24       61                    Abatacept
# 33729   3989  L04AA24       61                    Abatacept
# 222      223  L04AA24       61                    Abatacept
# ...      ...      ...      ...                          ...
# 24833  26030  M05BA08  531/530            Zoledronico Acido
# 20468  20913  M05BA08  531/530            Zoledronico Acido
# 20467  20912  M05BA08  531/530            Zoledronico Acido
# 20481  20930  M05BA08  531/530            Zoledronico Acido
# 50683  20942  M05BA08  531/530            Zoledronico Acido
#
#                 Forma Farmacéutica         CUM  \
# 30011  Líquido/Sólido - Inyectable  20041743-1
# 30012  Líquido/Sólido - Inyectable  20041743-2
# 33728  Líquido/Sólido - Inyectable  20041743-4
# 33729  Líquido/Sólido - Inyectable  20041743-3
# ...

# %%
#Grafico de Torta
import matplotlib.pyplot as plt

sizes = [5, 17, 20, 24, 31, 36, 41]
values = ['Solido', 'Inyectable', 'Inhalado', 'Oftalmico', 'Semisolido', 'Suspensión', 'Enema']

plt.pie(sizes, labels=values, autopct='%1.1f%%')
plt.title('Gráfico de Torta Porcentajes de Formas Farmacéuticas')
plt.show()

# %%
# Grafico de barras apiladas
import matplotlib.pyplot as plt

categories = ['Solido', 'Inyectable', 'Inhalado', 'Oftalmico', 'Semisolido', 'Suspensión']
values_one = [5, 17, 20, 24, 31, 36]
values_two = [50, 7, 31, 2, 10, 31]

categories = ['Solido', 'Inyectable', 'Inhalado', 'Oftalmico', 'Semisolido', 'Suspensión']
plt.bar(categories, values_one, label=['Solido', 'Inyectable', 'Inhalado', 'Oftalmico', 'Semisolido', 'Suspensión'])
plt.xlabel('Formas Farmacéuticas')
plt.ylabel('Cantidad en Porcentaje')
plt.title('Gráfico de Barras')
plt.legend()
plt.show()
